# %%
import talib
import json
import numpy as np
import pandas as pd
import requests
import datetime
from scipy.stats import gaussian_kde
import scipy as sp
from scipy import stats
from scipy.stats import ttest_ind_from_stats

# %% [markdown]
# Calculate Technical Indicators for Test Set

# %%
currency = pd.read_csv("chftest", sep = "\t")

# %% [markdown]
# http://mrjbq7.github.io/ta-lib/funcs.html
#
# Overlap Studies Functions

# %%
#
close = currency.Close.values
high = currency.High.values
low = currency.Low.values
ti = pd.DataFrame()
#BBANDS
ti['upperband3'], ti['middleband3'], ti['lowerband3'] = talib.BBANDS(currency.Close.values, timeperiod=3, nbdevup=2, nbdevdn=2, matype=0)
ti['upperband5'], ti['middleband5'], ti['lowerband5'] = talib.BBANDS(currency.Close.values, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
ti['upperband9'], ti['middleband9'], ti['lowerband9'] = talib.BBANDS(currency.Close.values, timeperiod=9, nbdevup=2, nbdevdn=2, matype=0)
ti['upperband12'], ti['middleband12'], ti['lowerband12'] = talib.BBANDS(currency.Close.values, timeperiod=12, nbdevup=2, nbdevdn=2, matype=0)
ti['upperband20'], ti['middleband20'], ti['lowerband20'] = talib.BBANDS(currency.Close.values, timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)
#DEMA
ti['dema3'] = talib.DEMA(currency.Close.values, timeperiod=3)
ti['dema5'] = talib.DEMA(currency.Close.values, timeperiod=5)
ti['dema9'] = talib.DEMA(currency.Close.values, timeperiod=9)
ti['dema12'] = talib.DEMA(currency.Close.values, timeperiod=12)
ti['dema20'] = talib.DEMA(currency.Close.values, timeperiod=20)
#EMA
ti['ema3'] = talib.EMA(currency.Close.values, timeperiod=3)
ti['ema5'] = talib.EMA(currency.Close.values, timeperiod=5)
ti['ema9'] = talib.EMA(currency.Close.values, timeperiod=9)
ti['ema12'] = talib.EMA(currency.Close.values, timeperiod=12)
ti['ema20'] = talib.EMA(currency.Close.values, timeperiod=20)
#HT_TRENDLINE
ti['htt'] = talib.HT_TRENDLINE(currency.Close.values)
#KAMA - Kaufman Adaptive Moving Average
ti['kama3'] = talib.KAMA(currency.Close.values, timeperiod=3)
ti['kama5'] = talib.KAMA(currency.Close.values, timeperiod=5)
ti['kama9'] = talib.KAMA(currency.Close.values, timeperiod=9)
ti['kama12'] = talib.KAMA(currency.Close.values, timeperiod=12)
ti['kama20'] = talib.KAMA(currency.Close.values, timeperiod=20)
#MA - Moving average
ti['ma3'] = talib.MA(close, timeperiod=3, matype=0)
ti['ma5'] = talib.MA(close, timeperiod=5, matype=0)
ti['ma9'] = talib.MA(close, timeperiod=9, matype=0)
ti['ma12'] = talib.MA(close, timeperiod=12, matype=0)
ti['ma20'] = talib.MA(close, timeperiod=20, matype=0)
#MAMA - MESA Adaptive Moving Average
ti['mama'], ti['fama'] = talib.MAMA(close, fastlimit=0.5, slowlimit=0.05)
#MAVP - Moving average with variable period
#mavp = talib.MAVP(close, period = 30, minperiod=2, maxperiod=30, matype=0)
#MIDPOINT - MidPoint over period
ti['mpoint3'] = talib.MIDPOINT(close, timeperiod=3)
ti['mpoint5'] = talib.MIDPOINT(close, timeperiod=5)
ti['mpoint9'] = talib.MIDPOINT(close, timeperiod=9)
ti['mpoint12'] = talib.MIDPOINT(close, timeperiod=12)
ti['mpoint20'] = talib.MIDPOINT(close, timeperiod=20)
#MIDPRICE - Midpoint Price over period
ti['mprice3'] = talib.MIDPRICE(currency.High.values, currency.Low.values, timeperiod=3)
ti['mprice5'] = talib.MIDPRICE(currency.High.values, currency.Low.values, timeperiod=5)
ti['mprice9'] = talib.MIDPRICE(currency.High.values, currency.Low.values, timeperiod=9)
ti['mprice12'] = talib.MIDPRICE(currency.High.values, currency.Low.values, timeperiod=12)
ti['mprice20'] = talib.MIDPRICE(currency.High.values, currency.Low.values, timeperiod=20)
#SAR - Parabolic SAR
ti['sar'] = talib.SAR(high, low)#, acceleration=0, maximum=0)
#SAREXT - Parabolic SAR - Extended
ti['sarext'] = talib.SAREXT(high, low)#, startvalue=0, offsetonreverse=0, accelerationinitlong=0, accelerationlong=0, accelerationmaxlong=0, accelerationinitshort=0, accelerationshort=0, accelerationmaxshort=0)
#SMA - Simple Moving Average
ti['sma3'] = talib.SMA(close, timeperiod=3)
ti['sma5'] = talib.SMA(close, timeperiod=5)
ti['sma9'] = talib.SMA(close, timeperiod=9)
ti['sma12'] = talib.SMA(close, timeperiod=12)
ti['sma20'] = talib.SMA(close, timeperiod=20)
#T3 - Triple Exponential Moving Average (T3)
ti['t3'] = talib.T3(close, timeperiod=3, vfactor=0)
ti['t5'] = talib.T3(close, timeperiod=5, vfactor=0)
ti['t9'] = talib.T3(close, timeperiod=9, vfactor=0)
ti['t12'] = talib.T3(close, timeperiod=12, vfactor=0)
ti['t20'] = talib.T3(close, timeperiod=20, vfactor=0)
#TEMA - Triple Exponential Moving Average
ti['tema3'] = talib.TEMA(close, timeperiod=3)
ti['tema5'] = talib.TEMA(close, timeperiod=5)
ti['tema9'] = talib.TEMA(close, timeperiod=9)
ti['tema12'] = talib.TEMA(close, timeperiod=12)
ti['tema20'] = talib.TEMA(close, timeperiod=20)
#TRIMA - Triangular Moving Average
ti['trima3'] = talib.TRIMA(close, timeperiod=3)
ti['trima5'] = talib.TRIMA(close, timeperiod=5)
ti['trima9'] = talib.TRIMA(close, timeperiod=9)
ti['trima12'] = talib.TRIMA(close, timeperiod=12)
ti['trima20'] = talib.TRIMA(close, timeperiod=20)
#WMA - Weighted Moving Average
ti['wma3'] = talib.WMA(close, timeperiod=3)
ti['wma5'] = talib.WMA(close, timeperiod=5)
ti['wma9'] = talib.WMA(close, timeperiod=9)
ti['wma12'] = talib.WMA(close, timeperiod=12)
ti['wma20'] = talib.WMA(close, timeperiod=20)

# %% [markdown]
# Momentum Indicator Functions

# %%
#
openn = currency.Open.values
#ADX - Average Directional Movement Index
ti['adx3'] = talib.ADX(high, low, close, timeperiod=3)
ti['adx5'] = talib.ADX(high, low, close, timeperiod=5)
ti['adx9'] = talib.ADX(high, low, close, timeperiod=9)
ti['adx12'] = talib.ADX(high, low, close, timeperiod=12)
ti['adx20'] = talib.ADX(high, low, close, timeperiod=20)
#ADXR - Average Directional Movement Index Rating
ti['adxr3'] = talib.ADXR(high, low, close, timeperiod=3)
ti['adxr5'] = talib.ADXR(high, low, close, timeperiod=5)
ti['adxr9'] = talib.ADXR(high, low, close, timeperiod=9)
ti['adxr12'] = talib.ADXR(high, low, close, timeperiod=12)
ti['adxr20'] = talib.ADXR(high, low, close, timeperiod=20)
#APO - Absolute Price Oscillator
ti['apo3'] = talib.APO(close, fastperiod=3, slowperiod=5, matype=0)
ti['apo5'] = talib.APO(close, fastperiod=5, slowperiod=9, matype=0)
ti['apo9'] = talib.APO(close, fastperiod=9, slowperiod=12, matype=0)
ti['apo12'] = talib.APO(close, fastperiod=12, slowperiod=20, matype=0)
ti['apo20'] = talib.APO(close, fastperiod=20, slowperiod=30, matype=0)
#AROON - Aroon
ti['aroondown3'], ti['aroonup3'] = talib.AROON(high, low, timeperiod=3)
ti['aroondown5'], ti['aroonup5'] = talib.AROON(high, low, timeperiod=5)
ti['aroondown9'], ti['aroonup9'] = talib.AROON(high, low, timeperiod=9)
ti['aroondown12'], ti['aroonup12'] = talib.AROON(high, low, timeperiod=12)
ti['aroondown20'], ti['aroonup20'] = talib.AROON(high, low, timeperiod=20)
#AROONOSC - Aroon Oscillator
ti['aroon3'] = talib.AROONOSC(high, low, timeperiod=3)
ti['aroon5'] = talib.AROONOSC(high, low, timeperiod=5)
ti['aroon9'] = talib.AROONOSC(high, low, timeperiod=9)
ti['aroon12'] = talib.AROONOSC(high, low, timeperiod=12)
ti['aroon20'] = talib.AROONOSC(high, low, timeperiod=20)
#BOP - Balance Of Power
ti['bop'] = talib.BOP(openn, high, low, close)
#CCI - Commodity Channel Index
ti['cci3'] = talib.CCI(high, low, close, timeperiod=3)
ti['cci5'] = talib.CCI(high, low, close, timeperiod=5)
ti['cci9'] = talib.CCI(high, low, close, timeperiod=9)
ti['cci12'] = talib.CCI(high, low, close, timeperiod=12)
ti['cci20'] = talib.CCI(high, low, close, timeperiod=20)
#CMO - Chande Momentum Oscillator
ti['cmo3'] = talib.CMO(close, timeperiod=3)
ti['cmo5'] = talib.CMO(close, timeperiod=5)
ti['cmo9'] = talib.CMO(close, timeperiod=9)
ti['cmo12'] = talib.CMO(close, timeperiod=12)
ti['cmo20'] = talib.CMO(close, timeperiod=20)
#DX - Directional Movement Index
ti['dx3'] = talib.DX(high, low, close, timeperiod=3)
ti['dx5'] = talib.DX(high, low, close, timeperiod=5)
ti['dx9'] = talib.DX(high, low, close, timeperiod=9)
ti['dx12'] = talib.DX(high, low, close, timeperiod=12)
ti['dx20'] = talib.DX(high, low, close, timeperiod=20)

#MACD - Moving Average Convergence/Divergence
ti['macdd3'], ti['macdssignal3'], ti['macdhhist3'] = talib.MACD(close, fastperiod=3, slowperiod=5, signalperiod=2)
ti['macdd5'], ti['macdssignal5'], ti['macdhhist5'] = talib.MACD(close, fastperiod=5, slowperiod=9, signalperiod=3)
ti['macdd9'], ti['macdssignal9'], ti['macdhhist9'] = talib.MACD(close, fastperiod=9, slowperiod=12, signalperiod=5)
ti['macdd12'], ti['macdssignal12'], ti['macdhhist12'] = talib.MACD(close, fastperiod=12, slowperiod=20, signalperiod=9)
ti['macdd20'], ti['macdssignal20'], ti['macdhhist20'] = talib.MACD(close, fastperiod=20, slowperiod=30, signalperiod=20)
#MACDEXT - MACD with controllable MA type
ti['macddd3'], ti['macdsssignal3'], ti['macdhhhist3'] = talib.MACDEXT(close, fastperiod=3, fastmatype=0, slowperiod=5, slowmatype=0, signalperiod=2, signalmatype=0)
ti['macddd5'], ti['macdsssignal5'], ti['macdhhhist5'] = talib.MACDEXT(close, fastperiod=5, fastmatype=0, slowperiod=9, slowmatype=0, signalperiod=3, signalmatype=0)
ti['macddd9'], ti['macdsssignal9'], ti['macdhhhist9'] = talib.MACDEXT(close, fastperiod=9, fastmatype=0, slowperiod=12, slowmatype=0, signalperiod=5, signalmatype=0)
ti['macddd12'], ti['macdsssignal12'], ti['macdhhhist12'] = talib.MACDEXT(close, fastperiod=12, fastmatype=0, slowperiod=20, slowmatype=0, signalperiod=9, signalmatype=0)
ti['macddd20'], ti['macdsssignal20'], ti['macdhhhist20'] = talib.MACDEXT(close, fastperiod=20, fastmatype=0, slowperiod=30, slowmatype=0, signalperiod=12, signalmatype=0)
#MACDFIX - Moving Average Convergence/Divergence Fix 12/26
ti['macdddd3'], ti['macdsignal3'], ti['macdhist3'] = talib.MACDFIX(close, signalperiod=3)
ti['macdddd5'], ti['macdsignal5'], ti['macdhist5'] = talib.MACDFIX(close, signalperiod=5)
ti['macdddd9'], ti['macdsignal9'], ti['macdhist9'] = talib.MACDFIX(close, signalperiod=9)
ti['macdddd12'], ti['macdsignal12'], ti['macdhist12'] = talib.MACDFIX(close, signalperiod=12)
ti['macdddd20'], ti['macdsignal20'], ti['macdhist20'] = talib.MACDFIX(close, signalperiod=20)
#MFI - Money Flow Index
####mfi = MFI(high, low, close, volume, timeperiod=14)
#MINUS_DI - Minus Directional Indicator
ti['minusdi3'] = talib.MINUS_DI(high, low, close, timeperiod=3)
ti['minusdi5'] = talib.MINUS_DI(high, low, close, timeperiod=5)
ti['minusdi9'] = talib.MINUS_DI(high, low, close, timeperiod=9)
ti['minusdi12'] = talib.MINUS_DI(high, low, close, timeperiod=12)
ti['minusdi20'] = talib.MINUS_DI(high, low, close, timeperiod=20)
#MINUS_DM - Minus Directional Movement
ti['minusdm3'] = talib.MINUS_DM(high, low, timeperiod=3)
ti['minusdm5'] = talib.MINUS_DM(high, low, timeperiod=5)
ti['minusdm9'] = talib.MINUS_DM(high, low, timeperiod=9)
ti['minusdm12'] = talib.MINUS_DM(high, low, timeperiod=12)
ti['minusdm20'] = talib.MINUS_DM(high, low, timeperiod=20)
#MOM - Momentum
ti['mom3'] = talib.MOM(close, timeperiod=3)
ti['mom5'] = talib.MOM(close, timeperiod=5)
ti['mom9'] = talib.MOM(close, timeperiod=9)
ti['mom12'] = talib.MOM(close, timeperiod=12)
ti['mom20'] = talib.MOM(close, timeperiod=20)
#PLUS_DI - Plus Directional Indicator
ti['plusdi3'] = talib.PLUS_DI(high, low, close, timeperiod=3)
ti['plusdi5'] = talib.PLUS_DI(high, low, close, timeperiod=5)
ti['plusdi9'] = talib.PLUS_DI(high, low, close, timeperiod=9)
ti['plusdi12'] = talib.PLUS_DI(high, low, close, timeperiod=12)
ti['plusdi20'] = talib.PLUS_DI(high, low, close, timeperiod=20)
#PLUS_DM - Plus Directional Movement
ti['plusdm3'] = talib.PLUS_DM(high, low, timeperiod=3)
ti['plusdm5'] = talib.PLUS_DM(high, low, timeperiod=5)
ti['plusdm9'] = talib.PLUS_DM(high, low, timeperiod=9)
ti['plusdm12'] = talib.PLUS_DM(high, low, timeperiod=12)
ti['plusdm20'] = talib.PLUS_DM(high, low, timeperiod=20)
#PPO - Percentage Price Oscillator
ti['ppo3'] = talib.PPO(close, fastperiod=3, slowperiod=5, matype=0)
ti['ppo5'] = talib.PPO(close, fastperiod=5, slowperiod=9, matype=0)
ti['ppo9'] = talib.PPO(close, fastperiod=9, slowperiod=12, matype=0)
ti['ppo12'] = talib.PPO(close, fastperiod=12, slowperiod=20, matype=0)
ti['ppo20'] = talib.PPO(close, fastperiod=20, slowperiod=30, matype=0)
#ROC - Rate of change : ((price/prevPrice)-1)*100
ti['roc3'] = talib.ROC(close, timeperiod=3)
ti['roc5'] = talib.ROC(close, timeperiod=5)
ti['roc9'] = talib.ROC(close, timeperiod=9)
ti['roc12'] = talib.ROC(close, timeperiod=12)
ti['roc20'] = talib.ROC(close, timeperiod=20)
#ROCP - Rate of change Percentage: (price-prevPrice)/prevPrice
ti['rocp3'] = talib.ROCP(close, timeperiod=3)
ti['rocp5'] = talib.ROCP(close, timeperiod=5)
ti['rocp9'] = talib.ROCP(close, timeperiod=9)
ti['rocp12'] = talib.ROCP(close, timeperiod=12)
ti['rocp20'] = talib.ROCP(close, timeperiod=20)
#ROCR - Rate of change ratio: (price/prevPrice)
ti['rocr3'] = talib.ROCR(close, timeperiod=3)
ti['rocr5'] = talib.ROCR(close, timeperiod=5)
ti['rocr9'] = talib.ROCR(close, timeperiod=9)
ti['rocr12'] = talib.ROCR(close, timeperiod=12)
ti['rocr20'] = talib.ROCR(close, timeperiod=20)
#ROCR100 - Rate of change ratio 100 scale: (price/prevPrice)*100
ti['rocr1003'] = talib.ROCR100(close, timeperiod=3)
ti['rocr1005'] = talib.ROCR100(close, timeperiod=5)
ti['rocr1009'] = talib.ROCR100(close, timeperiod=9)
ti['rocr10012'] = talib.ROCR100(close, timeperiod=12)
ti['rocr10020'] = talib.ROCR100(close, timeperiod=20)
#RSI - Relative Strength Index
ti['rsi3'] = talib.RSI(close, timeperiod=3)
ti['rsi5'] = talib.RSI(close, timeperiod=5)
ti['rsi9'] = talib.RSI(close, timeperiod=9)
ti['rsi12'] = talib.RSI(close, timeperiod=12)
ti['rsi20'] = talib.RSI(close, timeperiod=20)
#STOCH - Stochastic
ti['slowk3'], ti['slowd3'] = talib.STOCH(high, low, close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=2, slowd_matype=0)
ti['slowk5'], ti['slowd5'] = talib.STOCH(high, low, close, fastk_period=9, slowk_period=5, slowk_matype=0, slowd_period=3, slowd_matype=0)
ti['slowk9'], ti['slowd9'] = talib.STOCH(high, low, close, fastk_period=12, slowk_period=9, slowk_matype=0, slowd_period=5, slowd_matype=0)
ti['slowk12'], ti['slowd12'] = talib.STOCH(high, low, close, fastk_period=20, slowk_period=12, slowk_matype=0, slowd_period=9, slowd_matype=0)
ti['slowk20'], ti['slowd20'] = talib.STOCH(high, low, close, fastk_period=30, slowk_period=20, slowk_matype=0, slowd_period=12, slowd_matype=0)
#STOCHF - Stochastic Fast
ti['fastk3'], ti['fastd3'] = talib.STOCHF(high, low, close, fastk_period=5, fastd_period=3, fastd_matype=0)
ti['fastk5'], ti['fastd5'] = talib.STOCHF(high, low, close, fastk_period=9, fastd_period=5, fastd_matype=0)
ti['fastk9'], ti['fastd9'] = talib.STOCHF(high, low, close, fastk_period=12, fastd_period=9, fastd_matype=0)
ti['fastk12'], ti['fastd12'] = talib.STOCHF(high, low, close, fastk_period=20, fastd_period=12, fastd_matype=0)
ti['fastk20'], ti['fastd20'] = talib.STOCHF(high, low, close, fastk_period=30, fastd_period=20, fastd_matype=0)
#STOCHRSI - Stochastic Relative Strength Index
ti['fastkk3'], ti['fastdd3'] = talib.STOCHRSI(close, timeperiod=5, fastk_period=3, fastd_period=2, fastd_matype=0)
ti['fastkk5'], ti['fastdd5'] = talib.STOCHRSI(close, timeperiod=9, fastk_period=5, fastd_period=3, fastd_matype=0)
ti['fastkk9'], ti['fastdd9'] = talib.STOCHRSI(close, timeperiod=12, fastk_period=9, fastd_period=5, fastd_matype=0)
ti['fastkk12'], ti['fastdd12'] = talib.STOCHRSI(close, timeperiod=20, fastk_period=12, fastd_period=9, fastd_matype=0)
ti['fastkk20'], ti['fastdd20'] = talib.STOCHRSI(close, timeperiod=30, fastk_period=20, fastd_period=12, fastd_matype=0)
#TRIX - 1-day Rate-Of-Change (ROC) of a Triple Smooth EMA
ti['trix3'] = talib.TRIX(close, timeperiod=3)
ti['trix5'] = talib.TRIX(close, timeperiod=5)
ti['trix9'] = talib.TRIX(close, timeperiod=9)
ti['trix12'] = talib.TRIX(close, timeperiod=12)
ti['trix20'] = talib.TRIX(close, timeperiod=20)
#ULTOSC - Ultimate Oscillator
ti['ultosc3'] = talib.ULTOSC(high, low, close, timeperiod1=2, timeperiod2=3, timeperiod3=5)
ti['ultosc5'] = talib.ULTOSC(high, low, close, timeperiod1=3, timeperiod2=5, timeperiod3=9)
ti['ultosc9'] = talib.ULTOSC(high, low, close, timeperiod1=5, timeperiod2=9, timeperiod3=12)
ti['ultosc12'] = talib.ULTOSC(high, low, close, timeperiod1=9, timeperiod2=12, timeperiod3=20)
ti['ultosc20'] = talib.ULTOSC(high, low, close, timeperiod1=12, timeperiod2=20, timeperiod3=30)
#WILLR - Williams' %R
ti['willr3'] = talib.WILLR(high, low, close, timeperiod=3)
ti['willr5'] = talib.WILLR(high, low, close, timeperiod=5)
ti['willr9'] = talib.WILLR(high, low, close, timeperiod=9)
ti['willr12'] = talib.WILLR(high, low, close, timeperiod=12)
ti['willr20'] = talib.WILLR(high, low, close, timeperiod=20)

# %%
ti.to_csv('tichftest', sep='\t', index = False)
#ti.to_csv('titest', sep='\t', index = False)

# %% [markdown]
# Calculate Technical Indicators for Training Set

# %%
currency = pd.read_csv("chftrain", sep = "\t")

# %% [markdown]
# Overlap Studies Functions

# %%
#
close = currency.Close.values
high = currency.High.values
low = currency.Low.values
ti = pd.DataFrame()
#BBANDS
ti['upperband3'], ti['middleband3'], ti['lowerband3'] = talib.BBANDS(currency.Close.values, timeperiod=3, nbdevup=2, nbdevdn=2, matype=0)
ti['upperband5'], ti['middleband5'], ti['lowerband5'] = talib.BBANDS(currency.Close.values, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
ti['upperband9'], ti['middleband9'], ti['lowerband9'] = talib.BBANDS(currency.Close.values, timeperiod=9, nbdevup=2, nbdevdn=2, matype=0)
ti['upperband12'], ti['middleband12'], ti['lowerband12'] = talib.BBANDS(currency.Close.values, timeperiod=12, nbdevup=2, nbdevdn=2, matype=0)
ti['upperband20'], ti['middleband20'], ti['lowerband20'] = talib.BBANDS(currency.Close.values, timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)
#DEMA
ti['dema3'] = talib.DEMA(currency.Close.values, timeperiod=3)
ti['dema5'] = talib.DEMA(currency.Close.values, timeperiod=5)
ti['dema9'] = talib.DEMA(currency.Close.values, timeperiod=9)
ti['dema12'] = talib.DEMA(currency.Close.values, timeperiod=12)
ti['dema20'] = talib.DEMA(currency.Close.values, timeperiod=20)
#EMA
ti['ema3'] = talib.EMA(currency.Close.values, timeperiod=3)
ti['ema5'] = talib.EMA(currency.Close.values, timeperiod=5)
ti['ema9'] = talib.EMA(currency.Close.values, timeperiod=9)
ti['ema12'] = talib.EMA(currency.Close.values, timeperiod=12)
ti['ema20'] = talib.EMA(currency.Close.values, timeperiod=20)
#HT_TRENDLINE
ti['htt'] = talib.HT_TRENDLINE(currency.Close.values)
#KAMA - Kaufman Adaptive Moving Average
ti['kama3'] = talib.KAMA(currency.Close.values, timeperiod=3)
ti['kama5'] = talib.KAMA(currency.Close.values, timeperiod=5)
ti['kama9'] = talib.KAMA(currency.Close.values, timeperiod=9)
ti['kama12'] = talib.KAMA(currency.Close.values, timeperiod=12)
ti['kama20'] = talib.KAMA(currency.Close.values, timeperiod=20)
#MA - Moving average
ti['ma3'] = talib.MA(close, timeperiod=3, matype=0)
ti['ma5'] = talib.MA(close, timeperiod=5, matype=0)
ti['ma9'] = talib.MA(close, timeperiod=9, matype=0)
ti['ma12'] = talib.MA(close, timeperiod=12, matype=0)
ti['ma20'] = talib.MA(close, timeperiod=20, matype=0)
#MAMA - MESA Adaptive Moving Average
ti['mama'], ti['fama'] = talib.MAMA(close, fastlimit=0.5, slowlimit=0.05)
#MAVP - Moving average with variable period
#mavp = talib.MAVP(close, period = 30, minperiod=2, maxperiod=30, matype=0)
#MIDPOINT - MidPoint over period
ti['mpoint3'] = talib.MIDPOINT(close, timeperiod=3)
ti['mpoint5'] = talib.MIDPOINT(close, timeperiod=5)
ti['mpoint9'] = talib.MIDPOINT(close, timeperiod=9)
ti['mpoint12'] = talib.MIDPOINT(close, timeperiod=12)
ti['mpoint20'] = talib.MIDPOINT(close, timeperiod=20)
#MIDPRICE - Midpoint Price over period
ti['mprice3'] = talib.MIDPRICE(currency.High.values, currency.Low.values, timeperiod=3)
ti['mprice5'] = talib.MIDPRICE(currency.High.values, currency.Low.values, timeperiod=5)
ti['mprice9'] = talib.MIDPRICE(currency.High.values, currency.Low.values, timeperiod=9)
ti['mprice12'] = talib.MIDPRICE(currency.High.values, currency.Low.values, timeperiod=12)
ti['mprice20'] = talib.MIDPRICE(currency.High.values, currency.Low.values, timeperiod=20)
#SAR - Parabolic SAR
ti['sar'] = talib.SAR(high, low)#, acceleration=0, maximum=0)
#SAREXT - Parabolic SAR - Extended
ti['sarext'] = talib.SAREXT(high, low)#, startvalue=0, offsetonreverse=0, accelerationinitlong=0, accelerationlong=0, accelerationmaxlong=0, accelerationinitshort=0, accelerationshort=0, accelerationmaxshort=0)
#SMA - Simple Moving Average
ti['sma3'] = talib.SMA(close, timeperiod=3)
ti['sma5'] = talib.SMA(close, timeperiod=5)
ti['sma9'] = talib.SMA(close, timeperiod=9)
ti['sma12'] = talib.SMA(close, timeperiod=12)
ti['sma20'] = talib.SMA(close, timeperiod=20)
#T3 - Triple Exponential Moving Average (T3)
ti['t3'] = talib.T3(close, timeperiod=3, vfactor=0)
ti['t5'] = talib.T3(close, timeperiod=5, vfactor=0)
ti['t9'] = talib.T3(close, timeperiod=9, vfactor=0)
ti['t12'] = talib.T3(close, timeperiod=12, vfactor=0)
ti['t20'] = talib.T3(close, timeperiod=20, vfactor=0)
#TEMA - Triple Exponential Moving Average
ti['tema3'] = talib.TEMA(close, timeperiod=3)
ti['tema5'] = talib.TEMA(close, timeperiod=5)
ti['tema9'] = talib.TEMA(close, timeperiod=9)
ti['tema12'] = talib.TEMA(close, timeperiod=12)
ti['tema20'] = talib.TEMA(close, timeperiod=20)
#TRIMA - Triangular Moving Average
ti['trima3'] = talib.TRIMA(close, timeperiod=3)
ti['trima5'] = talib.TRIMA(close, timeperiod=5)
ti['trima9'] = talib.TRIMA(close, timeperiod=9)
ti['trima12'] = talib.TRIMA(close, timeperiod=12)
ti['trima20'] = talib.TRIMA(close, timeperiod=20)
#WMA - Weighted Moving Average
ti['wma3'] = talib.WMA(close, timeperiod=3)
ti['wma5'] = talib.WMA(close, timeperiod=5)
ti['wma9'] = talib.WMA(close, timeperiod=9)
ti['wma12'] = talib.WMA(close, timeperiod=12)
ti['wma20'] = talib.WMA(close, timeperiod=20)

# %% [markdown]
# Momentum Indicator Functions

# %%
#
openn = currency.Open.values
#ADX - Average Directional Movement Index
ti['adx3'] = talib.ADX(high, low, close, timeperiod=3)
ti['adx5'] = talib.ADX(high, low, close, timeperiod=5)
ti['adx9'] = talib.ADX(high, low, close, timeperiod=9)
ti['adx12'] = talib.ADX(high, low, close, timeperiod=12)
ti['adx20'] = talib.ADX(high, low, close, timeperiod=20)
#ADXR - Average Directional Movement Index Rating
ti['adxr3'] = talib.ADXR(high, low, close, timeperiod=3)
ti['adxr5'] = talib.ADXR(high, low, close, timeperiod=5)
ti['adxr9'] = talib.ADXR(high, low, close, timeperiod=9)
ti['adxr12'] = talib.ADXR(high, low, close, timeperiod=12)
ti['adxr20'] = talib.ADXR(high, low, close, timeperiod=20)
#APO - Absolute Price Oscillator
ti['apo3'] = talib.APO(close, fastperiod=3, slowperiod=5, matype=0)
ti['apo5'] = talib.APO(close, fastperiod=5, slowperiod=9, matype=0)
ti['apo9'] = talib.APO(close, fastperiod=9, slowperiod=12, matype=0)
ti['apo12'] = talib.APO(close, fastperiod=12, slowperiod=20, matype=0)
ti['apo20'] = talib.APO(close, fastperiod=20, slowperiod=30, matype=0)
#AROON - Aroon
ti['aroondown3'], ti['aroonup3'] = talib.AROON(high, low, timeperiod=3)
ti['aroondown5'], ti['aroonup5'] = talib.AROON(high, low, timeperiod=5)
ti['aroondown9'], ti['aroonup9'] = talib.AROON(high, low, timeperiod=9)
ti['aroondown12'], ti['aroonup12'] = talib.AROON(high, low, timeperiod=12)
ti['aroondown20'], ti['aroonup20'] = talib.AROON(high, low, timeperiod=20)
#AROONOSC - Aroon Oscillator
ti['aroon3'] = talib.AROONOSC(high, low, timeperiod=3)
ti['aroon5'] = talib.AROONOSC(high, low, timeperiod=5)
ti['aroon9'] = talib.AROONOSC(high, low, timeperiod=9)
ti['aroon12'] = talib.AROONOSC(high, low, timeperiod=12)
ti['aroon20'] = talib.AROONOSC(high, low, timeperiod=20)
#BOP - Balance Of Power
ti['bop'] = talib.BOP(openn, high, low, close)
#CCI - Commodity Channel Index
ti['cci3'] = talib.CCI(high, low, close, timeperiod=3)
ti['cci5'] = talib.CCI(high, low, close, timeperiod=5)
ti['cci9'] = talib.CCI(high, low, close, timeperiod=9)
ti['cci12'] = talib.CCI(high, low, close, timeperiod=12)
ti['cci20'] = talib.CCI(high, low, close, timeperiod=20)
#CMO - Chande Momentum Oscillator
ti['cmo3'] = talib.CMO(close, timeperiod=3)
ti['cmo5'] = talib.CMO(close, timeperiod=5)
ti['cmo9'] = talib.CMO(close, timeperiod=9)
ti['cmo12'] = talib.CMO(close, timeperiod=12)
ti['cmo20'] = talib.CMO(close, timeperiod=20)
#DX - Directional Movement Index
ti['dx3'] = talib.DX(high, low, close, timeperiod=3)
ti['dx5'] = talib.DX(high, low, close, timeperiod=5)
ti['dx9'] = talib.DX(high, low, close, timeperiod=9)
ti['dx12'] = talib.DX(high, low, close, timeperiod=12)
ti['dx20'] = talib.DX(high, low, close, timeperiod=20)

#MACD - Moving Average Convergence/Divergence
ti['macdd3'], ti['macdssignal3'], ti['macdhhist3'] = talib.MACD(close, fastperiod=3, slowperiod=5, signalperiod=2)
ti['macdd5'], ti['macdssignal5'], ti['macdhhist5'] = talib.MACD(close, fastperiod=5, slowperiod=9, signalperiod=3)
ti['macdd9'], ti['macdssignal9'], ti['macdhhist9'] = talib.MACD(close, fastperiod=9, slowperiod=12, signalperiod=5)
ti['macdd12'], ti['macdssignal12'], ti['macdhhist12'] = talib.MACD(close, fastperiod=12, slowperiod=20, signalperiod=9)
ti['macdd20'], ti['macdssignal20'], ti['macdhhist20'] = talib.MACD(close, fastperiod=20, slowperiod=30, signalperiod=20)
#MACDEXT - MACD with controllable MA type
ti['macddd3'], ti['macdsssignal3'], ti['macdhhhist3'] = talib.MACDEXT(close, fastperiod=3, fastmatype=0, slowperiod=5, slowmatype=0, signalperiod=2, signalmatype=0)
ti['macddd5'], ti['macdsssignal5'], ti['macdhhhist5'] = talib.MACDEXT(close, fastperiod=5, fastmatype=0, slowperiod=9, slowmatype=0, signalperiod=3, signalmatype=0)
ti['macddd9'], ti['macdsssignal9'], ti['macdhhhist9'] = talib.MACDEXT(close, fastperiod=9, fastmatype=0, slowperiod=12, slowmatype=0, signalperiod=5, signalmatype=0)
ti['macddd12'], ti['macdsssignal12'], ti['macdhhhist12'] = talib.MACDEXT(close, fastperiod=12, fastmatype=0, slowperiod=20, slowmatype=0, signalperiod=9, signalmatype=0)
ti['macddd20'], ti['macdsssignal20'], ti['macdhhhist20'] = talib.MACDEXT(close, fastperiod=20, fastmatype=0, slowperiod=30, slowmatype=0, signalperiod=12, signalmatype=0)
#MACDFIX - Moving Average Convergence/Divergence Fix 12/26
ti['macdddd3'], ti['macdsignal3'], ti['macdhist3'] = talib.MACDFIX(close, signalperiod=3)
ti['macdddd5'], ti['macdsignal5'], ti['macdhist5'] = talib.MACDFIX(close, signalperiod=5)
ti['macdddd9'], ti['macdsignal9'], ti['macdhist9'] = talib.MACDFIX(close, signalperiod=9)
ti['macdddd12'], ti['macdsignal12'], ti['macdhist12'] = talib.MACDFIX(close, signalperiod=12)
ti['macdddd20'], ti['macdsignal20'], ti['macdhist20'] = talib.MACDFIX(close, signalperiod=20)
#MFI - Money Flow Index
####mfi = MFI(high, low, close, volume, timeperiod=14)
#MINUS_DI - Minus Directional Indicator
ti['minusdi3'] = talib.MINUS_DI(high, low, close, timeperiod=3)
ti['minusdi5'] = talib.MINUS_DI(high, low, close, timeperiod=5)
ti['minusdi9'] = talib.MINUS_DI(high, low, close, timeperiod=9)
ti['minusdi12'] = talib.MINUS_DI(high, low, close, timeperiod=12)
ti['minusdi20'] = talib.MINUS_DI(high, low, close, timeperiod=20)
#MINUS_DM - Minus Directional Movement
ti['minusdm3'] = talib.MINUS_DM(high, low, timeperiod=3)
ti['minusdm5'] = talib.MINUS_DM(high, low, timeperiod=5)
ti['minusdm9'] = talib.MINUS_DM(high, low, timeperiod=9)
ti['minusdm12'] = talib.MINUS_DM(high, low, timeperiod=12)
ti['minusdm20'] = talib.MINUS_DM(high, low, timeperiod=20)
#MOM - Momentum
ti['mom3'] = talib.MOM(close, timeperiod=3)
ti['mom5'] = talib.MOM(close, timeperiod=5)
ti['mom9'] = talib.MOM(close, timeperiod=9)
ti['mom12'] = talib.MOM(close, timeperiod=12)
ti['mom20'] = talib.MOM(close, timeperiod=20)
#PLUS_DI - Plus Directional Indicator
ti['plusdi3'] = talib.PLUS_DI(high, low, close, timeperiod=3)
ti['plusdi5'] = talib.PLUS_DI(high, low, close, timeperiod=5)
ti['plusdi9'] = talib.PLUS_DI(high, low, close, timeperiod=9)
ti['plusdi12'] = talib.PLUS_DI(high, low, close, timeperiod=12)
ti['plusdi20'] = talib.PLUS_DI(high, low, close, timeperiod=20)
#PLUS_DM - Plus Directional Movement
ti['plusdm3'] = talib.PLUS_DM(high, low, timeperiod=3)
ti['plusdm5'] = talib.PLUS_DM(high, low, timeperiod=5)
ti['plusdm9'] = talib.PLUS_DM(high, low, timeperiod=9)
ti['plusdm12'] = talib.PLUS_DM(high, low, timeperiod=12)
ti['plusdm20'] = talib.PLUS_DM(high, low, timeperiod=20)
#PPO - Percentage Price Oscillator
ti['ppo3'] = talib.PPO(close, fastperiod=3, slowperiod=5, matype=0)
ti['ppo5'] = talib.PPO(close, fastperiod=5, slowperiod=9, matype=0)
ti['ppo9'] = talib.PPO(close, fastperiod=9, slowperiod=12, matype=0)
ti['ppo12'] = talib.PPO(close, fastperiod=12, slowperiod=20, matype=0)
ti['ppo20'] = talib.PPO(close, fastperiod=20, slowperiod=30, matype=0)
#ROC - Rate of change : ((price/prevPrice)-1)*100
ti['roc3'] = talib.ROC(close, timeperiod=3)
ti['roc5'] = talib.ROC(close, timeperiod=5)
ti['roc9'] = talib.ROC(close, timeperiod=9)
ti['roc12'] = talib.ROC(close, timeperiod=12)
ti['roc20'] = talib.ROC(close, timeperiod=20)
#ROCP - Rate of change Percentage: (price-prevPrice)/prevPrice
ti['rocp3'] = talib.ROCP(close, timeperiod=3)
ti['rocp5'] = talib.ROCP(close, timeperiod=5)
ti['rocp9'] = talib.ROCP(close, timeperiod=9)
ti['rocp12'] = talib.ROCP(close, timeperiod=12)
ti['rocp20'] = talib.ROCP(close, timeperiod=20)
#ROCR - Rate of change ratio: (price/prevPrice)
ti['rocr3'] = talib.ROCR(close, timeperiod=3)
ti['rocr5'] = talib.ROCR(close, timeperiod=5)
ti['rocr9'] = talib.ROCR(close, timeperiod=9)
ti['rocr12'] = talib.ROCR(close, timeperiod=12)
ti['rocr20'] = talib.ROCR(close, timeperiod=20)
#ROCR100 - Rate of change ratio 100 scale: (price/prevPrice)*100
ti['rocr1003'] = talib.ROCR100(close, timeperiod=3)
ti['rocr1005'] = talib.ROCR100(close, timeperiod=5)
ti['rocr1009'] = talib.ROCR100(close, timeperiod=9)
ti['rocr10012'] = talib.ROCR100(close, timeperiod=12)
ti['rocr10020'] = talib.ROCR100(close, timeperiod=20)
#RSI - Relative Strength Index
ti['rsi3'] = talib.RSI(close, timeperiod=3)
ti['rsi5'] = talib.RSI(close, timeperiod=5)
ti['rsi9'] = talib.RSI(close, timeperiod=9)
ti['rsi12'] = talib.RSI(close, timeperiod=12)
ti['rsi20'] = talib.RSI(close, timeperiod=20)
#STOCH - Stochastic
ti['slowk3'], ti['slowd3'] = talib.STOCH(high, low, close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=2, slowd_matype=0)
ti['slowk5'], ti['slowd5'] = talib.STOCH(high, low, close, fastk_period=9, slowk_period=5, slowk_matype=0, slowd_period=3, slowd_matype=0)
ti['slowk9'], ti['slowd9'] = talib.STOCH(high, low, close, fastk_period=12, slowk_period=9, slowk_matype=0, slowd_period=5, slowd_matype=0)
ti['slowk12'], ti['slowd12'] = talib.STOCH(high, low, close, fastk_period=20, slowk_period=12, slowk_matype=0, slowd_period=9, slowd_matype=0)
ti['slowk20'], ti['slowd20'] = talib.STOCH(high, low, close, fastk_period=30, slowk_period=20, slowk_matype=0, slowd_period=12, slowd_matype=0)
#STOCHF - Stochastic Fast
ti['fastk3'], ti['fastd3'] = talib.STOCHF(high, low, close, fastk_period=5, fastd_period=3, fastd_matype=0)
ti['fastk5'], ti['fastd5'] = talib.STOCHF(high, low, close, fastk_period=9, fastd_period=5, fastd_matype=0)
ti['fastk9'], ti['fastd9'] = talib.STOCHF(high, low, close, fastk_period=12, fastd_period=9, fastd_matype=0)
ti['fastk12'], ti['fastd12'] = talib.STOCHF(high, low, close, fastk_period=20, fastd_period=12, fastd_matype=0)
ti['fastk20'], ti['fastd20'] = talib.STOCHF(high, low, close, fastk_period=30, fastd_period=20, fastd_matype=0)
#STOCHRSI - Stochastic Relative Strength Index
ti['fastkk3'], ti['fastdd3'] = talib.STOCHRSI(close, timeperiod=5, fastk_period=3, fastd_period=2, fastd_matype=0)
ti['fastkk5'], ti['fastdd5'] = talib.STOCHRSI(close, timeperiod=9, fastk_period=5, fastd_period=3, fastd_matype=0)
ti['fastkk9'], ti['fastdd9'] = talib.STOCHRSI(close, timeperiod=12, fastk_period=9, fastd_period=5, fastd_matype=0)
ti['fastkk12'], ti['fastdd12'] = talib.STOCHRSI(close, timeperiod=20, fastk_period=12, fastd_period=9, fastd_matype=0)
ti['fastkk20'], ti['fastdd20'] = talib.STOCHRSI(close, timeperiod=30, fastk_period=20, fastd_period=12, fastd_matype=0)
#TRIX - 1-day Rate-Of-Change (ROC) of a Triple Smooth EMA
ti['trix3'] = talib.TRIX(close, timeperiod=3)
ti['trix5'] = talib.TRIX(close, timeperiod=5)
ti['trix9'] = talib.TRIX(close, timeperiod=9)
ti['trix12'] = talib.TRIX(close, timeperiod=12)
ti['trix20'] = talib.TRIX(close, timeperiod=20)
#ULTOSC - Ultimate Oscillator
ti['ultosc3'] = talib.ULTOSC(high, low, close, timeperiod1=2, timeperiod2=3, timeperiod3=5)
ti['ultosc5'] = talib.ULTOSC(high, low, close, timeperiod1=3, timeperiod2=5, timeperiod3=9)
ti['ultosc9'] = talib.ULTOSC(high, low, close, timeperiod1=5, timeperiod2=9, timeperiod3=12)
ti['ultosc12'] = talib.ULTOSC(high, low, close, timeperiod1=9, timeperiod2=12, timeperiod3=20)
ti['ultosc20'] = talib.ULTOSC(high, low, close, timeperiod1=12, timeperiod2=20, timeperiod3=30)
#WILLR - Williams' %R
ti['willr3'] = talib.WILLR(high, low, close, timeperiod=3)
ti['willr5'] = talib.WILLR(high, low, close, timeperiod=5)
ti['willr9'] = talib.WILLR(high, low, close, timeperiod=9)
ti['willr12'] = talib.WILLR(high, low, close, timeperiod=12)
ti['willr20'] = talib.WILLR(high, low, close, timeperiod=20)

# %%
ti.to_csv('tichftrain', sep='\t', index = False)
#ti.to_csv('titest', sep='\t', index = False)
